# %% [markdown]
# ## Análise estatística de dados do ENEM 2019 - Estado de São Paulo
# Dados extraídos do INEP

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('../assets/microdados_enem_2019_sp.csv', sep=';', encoding='iso-8859-1') # normalmente é essa, utf-8 ou latin-1

# %% [markdown]
# #### Extração e limpeza

# %%
data.head(n=10)
# Out:
#   NU_INSCRICAO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0     1,90E+11                  3546801            Santa Isabel
# 1     1,90E+11                  3538204             Pinhalzinho
# 2     1,90E+11                  3550308               São Paulo
# 3     1,90E+11                  3548708   São Bernardo do Campo
# 4     1,90E+11                  3549409    São Joaquim da Barra
# 5     1,90E+11                  3515103              Embu-Guaçu
# 6     1,90E+11                  3549904     São José dos Campos
# 7     1,90E+11                  3549904     São José dos Campos
# 8     1,90E+11                  3518800               Guarulhos
# 9     1,90E+11                  3550308               São Paulo
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                35               SP        22       M                1
# 1                35               SP        19       M                1
# ...

# %%
# numero total de inscritos em SP foi de 813772, sendo 15,97% de todo o Brasil
data.shape
# Out:
# (813772, 44)

# %%
# analise dos tipos de cada coluna
data.dtypes
# Out:
# NU_INSCRICAO                object
# CO_MUNICIPIO_RESIDENCIA      int64
# NO_MUNICIPIO_RESIDENCIA     object
# CO_UF_RESIDENCIA             int64
# SG_UF_RESIDENCIA            object
# NU_IDADE                     int64
# TP_SEXO                     object
# TP_ESTADO_CIVIL              int64
# TP_COR_RACA                  int64
# TP_NACIONALIDADE             int64
# CO_MUNICIPIO_NASCIMENTO    float64
# NO_MUNICIPIO_NASCIMENTO     object
# CO_UF_NASCIMENTO           float64
# SG_UF_NASCIMENTO            object
# TP_ST_CONCLUSAO              int64
# TP_ANO_CONCLUIU              int64
# TP_ESCOLA                    int64
# TP_ENSINO                  float64
# IN_TREINEIRO                 int64
# CO_ESCOLA                  float64
# CO_MUNICIPIO_ESC           float64
# NO_MUNICIPIO_ESC            object
# CO_UF_ESC                  float64
# SG_UF_ESC                   object
# TP_DEPENDENCIA_ADM_ESC     float64
# TP_LOCALIZACAO_ESC         float64
# TP_SIT_FUNC_ESC            float64
# ...

# %%
# eliminando coluna
dados1 = data.drop(columns=['CO_MUNICIPIO_RESIDENCIA'])
# de 44 para 43 colunas
dados1
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0          1,90E+11            Santa Isabel                35
# 1          1,90E+11             Pinhalzinho                35
# 2          1,90E+11               São Paulo                35
# 3          1,90E+11   São Bernardo do Campo                35
# 4          1,90E+11    São Joaquim da Barra                35
# ...             ...                     ...               ...
# 813767     1,90E+11               São Paulo                35
# 813768     1,90E+11               São Paulo                35
# 813769     1,90E+11               São Paulo                35
# 813770     1,90E+11                 Cajamar                35
# 813771     1,90E+11                  Araras                35
#
#        SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0                    SP        22       M                1            3
# 1                    SP        19       M                1            3
# ...

# %%
dados1 = dados1.drop(columns=['CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA', 'CO_MUNICIPIO_NASCIMENTO'],)

# %%
dados1.head(30)
# Out:
#    NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0      1,90E+11            Santa Isabel        22       M                1
# 1      1,90E+11             Pinhalzinho        19       M                1
# 2      1,90E+11               São Paulo        17       F                1
# 3      1,90E+11   São Bernardo do Campo        19       M                1
# 4      1,90E+11    São Joaquim da Barra        37       M                2
# 5      1,90E+11              Embu-Guaçu        17       F                1
# 6      1,90E+11     São José dos Campos        28       F                1
# 7      1,90E+11     São José dos Campos        25       F                2
# 8      1,90E+11               Guarulhos        23       F                1
# 9      1,90E+11               São Paulo        19       F                1
# 10     1,90E+11   São José do Rio Preto        18       F                1
# ...

# %%
dados1 = dados1.drop(columns=[
    'NO_MUNICIPIO_NASCIMENTO',
    'CO_UF_NASCIMENTO',
    'SG_UF_NASCIMENTO',
    'TP_ANO_CONCLUIU',
    'TP_ENSINO',
    'CO_MUNICIPIO_ESC',
    'CO_UF_ESC',
    'SG_UF_ESC',
    'TP_DEPENDENCIA_ADM_ESC',
    'TP_LOCALIZACAO_ESC',
    'TP_SIT_FUNC_ESC',
],)

# %%
dados1.head(20)
# Out:
#    NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0      1,90E+11            Santa Isabel        22       M                1
# 1      1,90E+11             Pinhalzinho        19       M                1
# 2      1,90E+11               São Paulo        17       F                1
# 3      1,90E+11   São Bernardo do Campo        19       M                1
# 4      1,90E+11    São Joaquim da Barra        37       M                2
# 5      1,90E+11              Embu-Guaçu        17       F                1
# 6      1,90E+11     São José dos Campos        28       F                1
# 7      1,90E+11     São José dos Campos        25       F                2
# 8      1,90E+11               Guarulhos        23       F                1
# 9      1,90E+11               São Paulo        19       F                1
# 10     1,90E+11   São José do Rio Preto        18       F                1
# ...

# %%
dados1.shape
# Out:
# (813772, 29)
